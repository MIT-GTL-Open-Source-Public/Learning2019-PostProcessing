# %% [markdown]
# # Plotting teams exploration of tradespace over the theoretical traedspace

# %%
import os.path
from scipy.io import loadmat
import csv
import pandas

ANALYTICAL_TRADESPACE_FILE = os.path.expanduser("~/Learning2019Data/AnalyticalTradespace/data-2020-Jul-29_filtered.csv")
PARETO_FRONTS = [
    
    
]

PARETO_RANK_1 = [679302, 1007044, 386344, 3995, 175739, 319117, 30341, 555933, 15, 203924, 202799, 303541, 172225, 171314, 526342, 203684, 321745, 330786, 405556, 318974, 529306, 226403, 347761, 17199, 169425, 169384, 8847, 229491, 538774, 539103, 202577, 528176, 533904, 202722, 300703, 304333, 303505, 198554, 604938, 646489, 17143, 520370, 17144, 315148, 198338, 198287, 303744, 526191, 195651, 8846, 170788, 195647, 225896]
PARETO_RANK_2 = [679302, 1007044, 386344, 3995, 175739, 319117, 30341, 555933, 15, 203924, 202799, 303541, 172225, 171314, 526342, 203684, 321745, 330786, 405556, 318974, 529306, 226403, 347761, 17199, 169425, 169384, 8847, 229491, 538774, 539103, 202577, 528176, 533904, 202722, 300703, 304333, 303505, 198554, 604938, 646489, 17143, 520370, 17144, 315148, 198338, 198287, 303744, 526191, 195651, 8846, 170788, 195647, 225896, 23296, 726410, 22325, 621201, 38725, 226342, 668038, 338919, 347880, 347952, 296214, 29297, 300475, 232770, 198856, 218164, 576683, 295871, 319006, 300502, 8719, 8833, 303324, 550137, 203856, 203918, 316373, 350351, 202729, 199563, 198623, 207440, 558764, 318945, 315156, 318973, 300407, 18904, 8162, 519996, 300391, 19207, 317855, 373365, 17191, 525488, 329072, 371189, 308268, 317395, 308107, 300405, 169119, 304302, 300861, 169372, 525525, 224032, 610321, 198241, 8849, 17241, 20047, 209332, 198256, 520663, 316086, 198292, 303506, 198546, 507, 17576, 206838, 198510, 303463, 330130, 512281]
PARETO_RANK_2 = [x for x in PARETO_RANK_2 if x not in PARETO_RANK_1]


df = pandas.read_csv(ANALYTICAL_TRADESPACE_FILE)
df_p1 = df.loc[df['ID'].isin(PARETO_RANK_1)]
df_p2 = df.loc[df['ID'].isin(PARETO_RANK_2)]

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

df_p1 = df_p1.sort_values('cost')
df_p2 = df_p2.sort_values('cost')


GOLDEN_RATIO = np.array([1.61803398875, 1])
plt.figure(figsize=GOLDEN_RATIO*8)

plt.plot(df['cost']/1e6, df['interaction_score'], marker="o", linewidth=0, 
         markersize=5, fillstyle='full', alpha=0.5)
plt.plot(df_p1['cost']/1e6, df_p1['interaction_score'], marker="o", linewidth=3, 
         markersize=5, fillstyle='full', alpha=1.0)
# plt.plot(df_p2['cost']/1e6, df_p2['interaction_score'], marker="o", linewidth=3, 
#          markersize=5, fillstyle='full', alpha=1.0)

plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Interaction Score (relative)')
plt.show()

# %%
plt.figure(figsize=GOLDEN_RATIO*8)

plt.plot(df['cost']/1e6, df['team_mix'], marker="o", linewidth=0, 
         markersize=5, fillstyle='full', alpha=0.5)
plt.plot(df_p1['cost']/1e6, df_p1['team_mix'], marker="o", linewidth=3, 
         markersize=5, fillstyle='full', alpha=1.0)
# plt.plot(df_p2['cost']/1e6, df_p2['team_mix'], marker="o", linewidth=3, 
#          markersize=5, fillstyle='full', alpha=1.0)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Diversity Score (relative)')
plt.show()

# %%
plt.figure(figsize=GOLDEN_RATIO*8)

plt.plot(df['cost']/1e6, df['walking_time'], marker="o", linewidth=0, 
         markersize=5, fillstyle='full', alpha=0.5)
plt.plot(df_p1['cost']/1e6, df_p1['walking_time'], marker="o", linewidth=3, 
         markersize=5, fillstyle='full', alpha=1.0)
# plt.plot(df_p2['cost']/1e6, df_p2['walking_time'], marker="o", linewidth=3, 
#          markersize=5, fillstyle='full', alpha=1.0)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Walking Time (minutes)')
plt.show()
