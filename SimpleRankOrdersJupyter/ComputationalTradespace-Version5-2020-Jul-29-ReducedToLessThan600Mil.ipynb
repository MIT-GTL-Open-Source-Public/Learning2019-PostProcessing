# %% [markdown]
# # Plotting teams exploration of tradespace over the theoretical traedspace

# %%
import os.path
from scipy.io import loadmat
import csv
import pandas

ANALYTICAL_TRADESPACE_FILE = os.path.expanduser("~/Learning2019Data/AnalyticalTradespace/data-2020-Jul-29.csv")
FILTERED_DATA_OUT = os.path.expanduser("~/Learning2019Data/AnalyticalTradespace/data-2020-Jul-29_filtered.csv")
data_all = pandas.read_csv(ANALYTICAL_TRADESPACE_FILE)
data_fil = data_all[data_all['cost'] < 600e6]
data_fil.to_csv(FILTERED_DATA_OUT)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

GOLDEN_RATIO = np.array([1.61803398875, 1])
plt.figure(figsize=GOLDEN_RATIO*8)

plt.plot(data_600['cost']/1e6, data_600['interaction_score'], marker="o", linewidth=0, 
         markersize=5, fillstyle='full', alpha=0.5)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Interaction Score (relative)')
plt.show()

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

GOLDEN_RATIO = np.array([1.61803398875, 1])
plt.figure(figsize=GOLDEN_RATIO*8)

plt.plot(totalCost, diversityScore, marker="o", markeredgewidth=0,
         linewidth=0, markersize=5, fillstyle='full', alpha=0.005)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Diversity Score (relative)')
plt.show()

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

GOLDEN_RATIO = np.array([1.61803398875, 1])
plt.figure(figsize=GOLDEN_RATIO*8)

plt.plot(totalCost, timeCampus, marker="o", linewidth=0, markersize=5, fillstyle='full', alpha=0.005)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Walking Time (minutes)')
plt.show()

# %%
plt.figure(figsize=GOLDEN_RATIO*8)
plt.plot(totalCost, interactionScore, marker="o", linewidth=0, markersize=5, fillstyle='full', alpha=1.0)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Interaction Score (relative)')
plt.show()

plt.figure(figsize=GOLDEN_RATIO*8)
plt.plot(totalCost, diversityScore, marker="o", markeredgewidth=0,
         linewidth=0, markersize=5, fillstyle='full', alpha=1.0)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Diversity Score (relative)')
plt.show()

plt.figure(figsize=GOLDEN_RATIO*8)
plt.plot(totalCost, timeCampus, marker="o", linewidth=0, markersize=5, fillstyle='full', alpha=1.0)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Walking Time (minutes)')
plt.show()

# %%
plt.figure(figsize=GOLDEN_RATIO*8)
plt.plot(totalCost, interactionScore, marker="o", linewidth=0, markersize=5, fillstyle='full', alpha=0.5)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Interaction Score (relative)')
plt.xlim([450, 700])
plt.ylim([0.038, 0.043])
plt.show()

plt.figure(figsize=GOLDEN_RATIO*8)
plt.plot(totalCost, diversityScore, marker="o", markeredgewidth=0,
         linewidth=0, markersize=5, fillstyle='full', alpha=0.5)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Diversity Score (relative)')
plt.xlim([450, 700])
plt.ylim([0.6, 1.05])
plt.show()

plt.figure(figsize=GOLDEN_RATIO*8)
plt.plot(totalCost, timeCampus, marker="o", linewidth=0, markersize=5, fillstyle='full', alpha=0.5)
plt.xlabel ('Total Cost (millions of USD)')
plt.ylabel ('Walking Time (minutes)')
plt.xlim([450, 700])
plt.show()

# %%
totalCost600 = [x for x in totalCost if x < 600]

# %%
len(totalCost600)
# Out:
# 124740
