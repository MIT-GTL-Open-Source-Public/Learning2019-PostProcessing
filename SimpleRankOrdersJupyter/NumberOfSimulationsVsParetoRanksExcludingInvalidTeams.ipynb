# %% [markdown]
# # Number of Simulations vs. Pareto Ranks by Team (excluding invalid teams)
#
# This notebook explores the number of simulations that were done by team and grouped by
# their experimental condition and plots them against their Pareto ranks.

# %%
import sys
import os.path

sys.path.append("../CommonModules") # go to parent dir/CommonModules

import Learning2019GTL.Globals as Globals
import Learning2019GTL.DataConnector as DataConnector

data_map = Globals.FileNameMaps()

TEAM_MAP = dict([[v,k] for k,v in data_map.CSV_MAP.items()])
INVALID_TEAMS = [2, 23, 32, 39, 44, 47, 48]

DATA_FILE = os.path.expanduser("~/Learning2019Data/PostProcessingResults/TeamNumSimulationsByFile.csv")
DATA_FILE_PARETO = os.path.expanduser("~/Learning2019Data/PostProcessingResults/ParetoRankingByFile.csv")

import csv
import numpy as np

conditions = ['A - control (discuss conference) at beginning', 'B - strategy at beginning', 'D - strategy at mid']

class AnalyzedData:
    team_str   = ''
    team = None
    unique_sims = -1
    total_sims  = -1
    condition  = ''
    pareto_ranks_coarse = -1 # one or more solutions to be the same rank
    pareto_ranks_fine   = -1 # more solutions in the front == better rank
    pareto_ranks_ordinal = -1 # ordinal from pareto_ranks_fine
    
    def __str__(self):
        return str(self.team) + f", total_sims: {self.total_sims}, " +\
            f"unique_sims: {self.unique_sims}, " +\
            f"pareto_rank: {self.pareto_ranks_fine}, pareto_rank_ordinal: {self.pareto_ranks_ordinal}"
    
analyzed_data = {} # empty dictionary

with open(DATA_FILE, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        team_file = row['File']
        team_str = TEAM_MAP[team_file]
        t = DataConnector.Team()
        condition = t.getCondition(team_str)[0]
        if t.team_id in INVALID_TEAMS:
            print(f'Team {t.team_id} excluded, condition: {condition}')
            continue
        #print(row)
        #print(condition
        if team_str in analyzed_data.keys():
            datum = analyzed_data[team_str]
        else:
            datum = AnalyzedData()
            analyzed_data[team_str] = datum
            datum.team_str = team_str
            t.getTeamByID(t.team_id)
            datum.team = t
            
        datum.condition = condition
        datum.unique_sims = int(row[' UniqueSims'])
        datum.total_sims = int(row[' TotalSims'])
# Out:
# Team 39 excluded, condition: D
# Team 47 excluded, condition: B
# Team 23 excluded, condition: A
# Team 2 excluded, condition: A
# Team 44 excluded, condition: A
# Team 48 excluded, condition: A
# Team 32 excluded, condition: B

# %% [markdown]
# ## Checking that I can get back data grouped by conditions for plotting

# %%
uniqueSimsA = [analyzed_data[k].unique_sims for k in analyzed_data.keys() if analyzed_data[k].condition == 'A' ]
uniqueSimsB = [analyzed_data[k].unique_sims for k in analyzed_data.keys() if analyzed_data[k].condition == 'B' ]
uniqueSimsD = [analyzed_data[k].unique_sims for k in analyzed_data.keys() if analyzed_data[k].condition == 'D' ]

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt


font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

golden_ratio = np.array([1.61803398875, 1])
plt.figure(figsize=golden_ratio*8)

uniqueSimsA = np.array(uniqueSimsA)
uniqueSimsB = np.array(uniqueSimsB)
uniqueSimsD = np.array(uniqueSimsD)

plt.hist(uniqueSimsA-1/6, bins=np.arange(0, 18, 1/6), density=False)
plt.hist(uniqueSimsB+0/6, bins=np.arange(0, 18, 1/6), density=False)
plt.hist(uniqueSimsD+1/6, bins=np.arange(0, 18, 1/6), density=False)
plt.xlim([3, 16])
plt.legend(conditions, fontsize=12, loc='upper right')
plt.ylabel('Number of Teams')
plt.xlabel('Number of Unique Simulations')
plt.show()

# %% [markdown]
# ## Loading Pareto Ranks

# %%
def getPRank(row):
    rank = -1
    for p in range(17):
        key = f'P{p}'
        if int(row[key]) > 0:
            rank = p
            break
            
    return rank

def getPRankWithNum(row):
    rank = -1
    for p in range(17):
        key = f'P{p}'
        val = int(row[key])
        if val > 0:
            rank = p + 1/(val + 1)
            break
            
    return rank

with open(DATA_FILE_PARETO, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        team_file = row['File']
        team_str = TEAM_MAP[team_file]
        rank_coarse = getPRank(row)
        rank_fine   = getPRankWithNum(row)
        # if we don't find team, skip as there were invalid teams
        # otherwise update pareto data
        if team_str in analyzed_data.keys():
            datum = analyzed_data[team_str]  
            datum.pareto_ranks_coarse = rank_coarse
            datum.pareto_ranks_fine   = rank_fine

# %% [markdown]
# ## Number of unique simulations verses pareto ranks

# %%
paretoRanksA = [analyzed_data[k].pareto_ranks_fine for k in analyzed_data.keys() if analyzed_data[k].condition == 'A' ]
paretoRanksB = [analyzed_data[k].pareto_ranks_fine for k in analyzed_data.keys() if analyzed_data[k].condition == 'B' ]
paretoRanksD = [analyzed_data[k].pareto_ranks_fine for k in analyzed_data.keys() if analyzed_data[k].condition == 'D' ]

allData = paretoRanksA + paretoRanksB + paretoRanksD

import scipy.stats
rankedData = scipy.stats.rankdata(allData, method='dense')
paretoRanksA = rankedData[0:len(paretoRanksA)]
paretoRanksB = rankedData[len(paretoRanksA):len(paretoRanksA)+len(paretoRanksB)]
paretoRanksD = rankedData[len(paretoRanksA)+len(paretoRanksB):]

plt.figure(figsize=golden_ratio*8)
plt.plot(uniqueSimsA, paretoRanksA, marker="s", linewidth=0, markersize=15)
plt.plot(uniqueSimsB, paretoRanksB, marker="o", linewidth=0, markersize=15)
plt.plot(uniqueSimsD, paretoRanksD, marker="d", linewidth=0, markersize=15)
plt.xlabel("Number of Unique Solutions Explored")
plt.ylabel("Pareto Onion-Peeling Rank \n(lower is better)")
plt.legend(conditions, fontsize=16, loc='upper left', bbox_to_anchor=(0,1.25))
plt.show()

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()  # create object for the class
linear_pred_X = np.arange(1, 20).reshape(-1, 1)
linear_regressor.fit(uniqueSimsA.reshape(-1,1), paretoRanksA)  # perform linear regression
print("A lin regression score: ", linear_regressor.score(uniqueSimsA.reshape(-1,1), paretoRanksA))
print("A lin coef: ", linear_regressor.coef_)
print("A lin intercept: ", linear_regressor.intercept_)

linearA_pred = linear_regressor.predict(linear_pred_X)  # make predictions

linear_regressor.fit(uniqueSimsB.reshape(-1,1), paretoRanksB)  # perform linear regression
print("B lin regression score: ", linear_regressor.score(uniqueSimsB.reshape(-1,1), paretoRanksB))
print("B lin coef: ", linear_regressor.coef_)
print("B lin intercept: ", linear_regressor.intercept_)

linearB_pred = linear_regressor.predict(linear_pred_X)  # make predictions

linear_regressor.fit(uniqueSimsD.reshape(-1,1), paretoRanksD)  # perform linear regression
print("D lin regression score: ", linear_regressor.score(uniqueSimsD.reshape(-1,1), paretoRanksD))
print("D lin coef: ", linear_regressor.coef_)
print("D lin intercept: ", linear_regressor.intercept_)

linearD_pred = linear_regressor.predict(linear_pred_X)  # make predictions
# Out:
# A lin regression score:  0.503070042941681
# A lin coef:  [0.76957164]
# A lin intercept:  -4.228951255539146
# B lin regression score:  0.1677442660370344
# B lin coef:  [-0.35657371]
# B lin intercept:  6.729083665338645
# D lin regression score:  0.3077153508187993
# D lin coef:  [-0.41505792]
# D lin intercept:  6.56949806949807

# %%
plt.figure(figsize=golden_ratio*8)
plt.plot(uniqueSimsA, paretoRanksA, marker="s", linewidth=0, markersize=15)
plt.plot(uniqueSimsB, paretoRanksB, marker="o", linewidth=0, markersize=15)
plt.plot(uniqueSimsD, paretoRanksD, marker="d", linewidth=0, markersize=15)
plt.plot(linear_pred_X, linearA_pred, color='#1f77d4', linewidth=3)
plt.plot(linear_pred_X, linearB_pred, color='#ff7f0e', linewidth=3)
plt.plot(linear_pred_X, linearD_pred, color='#2ca02c', linewidth=3)
plt.xlabel("Number of Unique Solutions Explored")
plt.ylabel("Pareto Onion-Peeling Rank \n(lower is better)")
plt.legend(conditions, fontsize=16, loc='upper left', bbox_to_anchor=(0,1.25))
plt.ylim([0.5, 11.5])
plt.xlim([3.5, 17.5])
plt.show()

# %%
plt.figure(figsize=golden_ratio*8)
plt.plot(uniqueSimsA, -paretoRanksA, marker="s", linewidth=0, markersize=15)
plt.plot(uniqueSimsB, -paretoRanksB, marker="o", linewidth=0, markersize=15)
plt.plot(uniqueSimsD, -paretoRanksD, marker="d", linewidth=0, markersize=15)
plt.plot(linear_pred_X, -linearA_pred, color='#1f77d4', linewidth=3)
plt.plot(linear_pred_X, -linearB_pred, color='#ff7f0e', linewidth=3)
plt.plot(linear_pred_X, -linearD_pred, color='#2ca02c', linewidth=3)
plt.xlabel("Number of Unique Solutions Explored")
plt.ylabel("Negative Pareto Onion-Peeling Rank \n(higher is better)")
plt.legend(conditions, fontsize=16, loc='upper left', bbox_to_anchor=(0,1.25))
plt.ylim([-11.5, -0.5])
plt.xlim([3.5, 17.5])
plt.show()

# %%
plt.figure(figsize=golden_ratio*8)
plt.plot(uniqueSimsA, paretoRanksA, marker="s", linewidth=0, markersize=15)
plt.plot(uniqueSimsB, paretoRanksB, marker="o", linewidth=0, markersize=15)
plt.plot(uniqueSimsD, paretoRanksD, marker="d", linewidth=0, markersize=15)
plt.plot(linear_pred_X, linearA_pred, color='#1f77d4', linewidth=3)
plt.plot(linear_pred_X, linearB_pred, color='#ff7f0e', linewidth=3)
plt.plot(linear_pred_X, linearD_pred, color='#2ca02c', linewidth=3)
plt.xlabel("Number of Unique Solutions Explored")
plt.ylabel("Pareto Onion-Peeling Rank \n(lower is better)")
plt.legend(conditions, fontsize=16, loc='upper left', bbox_to_anchor=(0,1.2))
plt.ylim([8.5, 0.5])
plt.xlim([3.5, 15.5])
plt.show()

# %% [markdown]
# # Teams that are highly and not-so-highly ranked in the various groups

# %%
for key in analyzed_data:
    datum = analyzed_data[key]
    print(datum)
# Out:
#  Day: M, Session: S3, Room: R2, Station: 7 Condition: D, DbTeamID: 15, total_sims: 7, unique_sims: 6, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: -1
#  Day: M, Session: S1, Room: R1, Station: 4 Condition: A, DbTeamID: 4, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 34, total_sims: 5, unique_sims: 5, pareto_rank: 4.333333333333333, pareto_rank_ordinal: -1
#  Day: T, Session: S1, Room: R1, Station: 4 Condition: B, DbTeamID: 26, total_sims: 13, unique_sims: 11, pareto_rank: 1.3333333333333333, pareto_rank_ordinal: -1
#  Day: T, Session: S1, Room: R2, Station: 7 Condition: D, DbTeamID: 27, total_sims: 6, unique_sims: 6, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: M, Session: S3, Room: R1, Station: 1 Condition: A, DbTeamID: 12, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S2, Room: R2, Station: 5 Condition: D, DbTeamID: 35, total_sims: 12, unique_sims: 11, pareto_rank: 1.2, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 8, total_sims: 11, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: T, Session: S3, Room: R2, Station: 5 Condition: A, DbTeamID: 43, total_sims: 18, unique_sims: 13, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: T, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 33, total_sims: 18, unique_sims: 14, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: -1
#  Day: T, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 31, total_sims: 13, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R2, Station: 7 Condition: D, DbTeamID: 9, total_sims: 8, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S4, Room: R1, Station: 2 Condition: B, DbTeamID: 45, total_sims: 14, unique_sims: 13, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R1, Station: 4 Condition: B, DbTeamID: 20, total_sims: 12, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S3, Room: R2, Station: 7 Condition: A, DbTeamID: 41, total_sims: 11, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S3, Room: R1, Station: 1 Condition: D, DbTeamID: 37, total_sims: 12, unique_sims: 11, pareto_rank: 1.25, pareto_rank_ordinal: -1
#  Day: T, Session: S4, Room: R2, Station: 5 Condition: A, DbTeamID: 49, total_sims: 12, unique_sims: 10, pareto_rank: 1.25, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R2, Station: 8 Condition: A, DbTeamID: 22, total_sims: 11, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S1, Room: R1, Station: 1 Condition: A, DbTeamID: 1, total_sims: 9, unique_sims: 9, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: M, Session: S3, Room: R1, Station: 3 Condition: A, DbTeamID: 13, total_sims: 18, unique_sims: 14, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: T, Session: S2, Room: R2, Station: 6 Condition: D, DbTeamID: 36, total_sims: 9, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S3, Room: R1, Station: 4 Condition: A, DbTeamID: 14, total_sims: 16, unique_sims: 12, pareto_rank: 1.3333333333333333, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R1, Station: 1 Condition: B, DbTeamID: 17, total_sims: 12, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 50, total_sims: 10, unique_sims: 9, pareto_rank: 1.25, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 5, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R2, Station: 7 Condition: A, DbTeamID: 21, total_sims: 14, unique_sims: 14, pareto_rank: 4.5, pareto_rank_ordinal: -1
#  Day: T, Session: S1, Room: R2, Station: 5 Condition: D, DbTeamID: 29, total_sims: 8, unique_sims: 4, pareto_rank: 4.333333333333333, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R1, Station: 2 Condition: B, DbTeamID: 6, total_sims: 14, unique_sims: 12, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 24, total_sims: 10, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 19, total_sims: 10, unique_sims: 7, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R1, Station: 3 Condition: B, DbTeamID: 7, total_sims: 11, unique_sims: 9, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R2, Station: 6 Condition: D, DbTeamID: 11, total_sims: 15, unique_sims: 15, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S1, Room: R2, Station: 6 Condition: D, DbTeamID: 30, total_sims: 9, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S1, Room: R1, Station: 1 Condition: B, DbTeamID: 25, total_sims: 6, unique_sims: 5, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: M, Session: S4, Room: R1, Station: 2 Condition: B, DbTeamID: 18, total_sims: 12, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 46, total_sims: 9, unique_sims: 8, pareto_rank: 1.5, pareto_rank_ordinal: -1
#  Day: T, Session: S3, Room: R2, Station: 8 Condition: A, DbTeamID: 42, total_sims: 14, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S3, Room: R1, Station: 4 Condition: D, DbTeamID: 40, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 10, total_sims: 11, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S3, Room: R2, Station: 8 Condition: D, DbTeamID: 16, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: T, Session: S1, Room: R2, Station: 8 Condition: D, DbTeamID: 28, total_sims: 10, unique_sims: 10, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: -1
#  Day: T, Session: S3, Room: R1, Station: 2 Condition: D, DbTeamID: 38, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: -1
#  Day: M, Session: S1, Room: R1, Station: 3 Condition: A, DbTeamID: 3, total_sims: 13, unique_sims: 12, pareto_rank: 1.5, pareto_rank_ordinal: -1

# %%
allData = [analyzed_data[k].pareto_ranks_fine for k in analyzed_data.keys()]
rankedData = scipy.stats.rankdata(allData, method='dense')
i = 0
for key, value in analyzed_data.items():
    value.pareto_ranks_ordinal = rankedData[i]
    i += 1

# %%
for key in analyzed_data:
    datum = analyzed_data[key]
    print(datum)
# Out:
#  Day: M, Session: S3, Room: R2, Station: 7 Condition: D, DbTeamID: 15, total_sims: 7, unique_sims: 6, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: M, Session: S1, Room: R1, Station: 4 Condition: A, DbTeamID: 4, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 34, total_sims: 5, unique_sims: 5, pareto_rank: 4.333333333333333, pareto_rank_ordinal: 7
#  Day: T, Session: S1, Room: R1, Station: 4 Condition: B, DbTeamID: 26, total_sims: 13, unique_sims: 11, pareto_rank: 1.3333333333333333, pareto_rank_ordinal: 5
#  Day: T, Session: S1, Room: R2, Station: 7 Condition: D, DbTeamID: 27, total_sims: 6, unique_sims: 6, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S3, Room: R1, Station: 1 Condition: A, DbTeamID: 12, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S2, Room: R2, Station: 5 Condition: D, DbTeamID: 35, total_sims: 12, unique_sims: 11, pareto_rank: 1.2, pareto_rank_ordinal: 3
#  Day: M, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 8, total_sims: 11, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S3, Room: R2, Station: 5 Condition: A, DbTeamID: 43, total_sims: 18, unique_sims: 13, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 33, total_sims: 18, unique_sims: 14, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: T, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 31, total_sims: 13, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S2, Room: R2, Station: 7 Condition: D, DbTeamID: 9, total_sims: 8, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S4, Room: R1, Station: 2 Condition: B, DbTeamID: 45, total_sims: 14, unique_sims: 13, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R1, Station: 4 Condition: B, DbTeamID: 20, total_sims: 12, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R2, Station: 7 Condition: A, DbTeamID: 41, total_sims: 11, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R1, Station: 1 Condition: D, DbTeamID: 37, total_sims: 12, unique_sims: 11, pareto_rank: 1.25, pareto_rank_ordinal: 4
#  Day: T, Session: S4, Room: R2, Station: 5 Condition: A, DbTeamID: 49, total_sims: 12, unique_sims: 10, pareto_rank: 1.25, pareto_rank_ordinal: 4
#  Day: M, Session: S4, Room: R2, Station: 8 Condition: A, DbTeamID: 22, total_sims: 11, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S1, Room: R1, Station: 1 Condition: A, DbTeamID: 1, total_sims: 9, unique_sims: 9, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S3, Room: R1, Station: 3 Condition: A, DbTeamID: 13, total_sims: 18, unique_sims: 14, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S2, Room: R2, Station: 6 Condition: D, DbTeamID: 36, total_sims: 9, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S3, Room: R1, Station: 4 Condition: A, DbTeamID: 14, total_sims: 16, unique_sims: 12, pareto_rank: 1.3333333333333333, pareto_rank_ordinal: 5
#  Day: M, Session: S4, Room: R1, Station: 1 Condition: B, DbTeamID: 17, total_sims: 12, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 50, total_sims: 10, unique_sims: 9, pareto_rank: 1.25, pareto_rank_ordinal: 4
#  Day: M, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 5, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R2, Station: 7 Condition: A, DbTeamID: 21, total_sims: 14, unique_sims: 14, pareto_rank: 4.5, pareto_rank_ordinal: 8
#  Day: T, Session: S1, Room: R2, Station: 5 Condition: D, DbTeamID: 29, total_sims: 8, unique_sims: 4, pareto_rank: 4.333333333333333, pareto_rank_ordinal: 7
#  Day: M, Session: S2, Room: R1, Station: 2 Condition: B, DbTeamID: 6, total_sims: 14, unique_sims: 12, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 24, total_sims: 10, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 19, total_sims: 10, unique_sims: 7, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S2, Room: R1, Station: 3 Condition: B, DbTeamID: 7, total_sims: 11, unique_sims: 9, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: M, Session: S2, Room: R2, Station: 6 Condition: D, DbTeamID: 11, total_sims: 15, unique_sims: 15, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S1, Room: R2, Station: 6 Condition: D, DbTeamID: 30, total_sims: 9, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S1, Room: R1, Station: 1 Condition: B, DbTeamID: 25, total_sims: 6, unique_sims: 5, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S4, Room: R1, Station: 2 Condition: B, DbTeamID: 18, total_sims: 12, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 46, total_sims: 9, unique_sims: 8, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S3, Room: R2, Station: 8 Condition: A, DbTeamID: 42, total_sims: 14, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R1, Station: 4 Condition: D, DbTeamID: 40, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 10, total_sims: 11, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S3, Room: R2, Station: 8 Condition: D, DbTeamID: 16, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S1, Room: R2, Station: 8 Condition: D, DbTeamID: 28, total_sims: 10, unique_sims: 10, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: T, Session: S3, Room: R1, Station: 2 Condition: D, DbTeamID: 38, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S1, Room: R1, Station: 3 Condition: A, DbTeamID: 3, total_sims: 13, unique_sims: 12, pareto_rank: 1.5, pareto_rank_ordinal: 6

# %%
paretoRanksA = [analyzed_data[k].pareto_ranks_ordinal for k in analyzed_data.keys() if analyzed_data[k].condition == 'A' ]
paretoRanksB = [analyzed_data[k].pareto_ranks_ordinal for k in analyzed_data.keys() if analyzed_data[k].condition == 'B' ]
paretoRanksD = [analyzed_data[k].pareto_ranks_ordinal for k in analyzed_data.keys() if analyzed_data[k].condition == 'D' ]

uniqueSimsA = [analyzed_data[k].unique_sims for k in analyzed_data.keys() if analyzed_data[k].condition == 'A' ]
uniqueSimsB = [analyzed_data[k].unique_sims for k in analyzed_data.keys() if analyzed_data[k].condition == 'B' ]
uniqueSimsD = [analyzed_data[k].unique_sims for k in analyzed_data.keys() if analyzed_data[k].condition == 'D' ]

# %%
plt.figure(figsize=golden_ratio*8)
plt.plot(uniqueSimsA, paretoRanksA, marker="s", linewidth=0, markersize=15)
plt.plot(uniqueSimsB, paretoRanksB, marker="o", linewidth=0, markersize=15)
plt.plot(uniqueSimsD, paretoRanksD, marker="d", linewidth=0, markersize=15)
plt.plot(linear_pred_X, linearA_pred, color='#1f77d4', linewidth=3)
plt.plot(linear_pred_X, linearB_pred, color='#ff7f0e', linewidth=3)
plt.plot(linear_pred_X, linearD_pred, color='#2ca02c', linewidth=3)
plt.xlabel("Number of Unique Solutions Explored")
plt.ylabel("Pareto Onion-Peeling Rank \n(lower is better)")
plt.legend(conditions, fontsize=16, loc='upper left', bbox_to_anchor=(0,1.25))
plt.ylim([0.5, 8.5])
plt.xlim([3.5, 15.5])
plt.show()

# %%
for key in analyzed_data:
    datum = analyzed_data[key]
    print(datum)
# Out:
#  Day: M, Session: S3, Room: R2, Station: 7 Condition: D, DbTeamID: 15, total_sims: 7, unique_sims: 6, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: M, Session: S1, Room: R1, Station: 4 Condition: A, DbTeamID: 4, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 34, total_sims: 5, unique_sims: 5, pareto_rank: 4.333333333333333, pareto_rank_ordinal: 7
#  Day: T, Session: S1, Room: R1, Station: 4 Condition: B, DbTeamID: 26, total_sims: 13, unique_sims: 11, pareto_rank: 1.3333333333333333, pareto_rank_ordinal: 5
#  Day: T, Session: S1, Room: R2, Station: 7 Condition: D, DbTeamID: 27, total_sims: 6, unique_sims: 6, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S3, Room: R1, Station: 1 Condition: A, DbTeamID: 12, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S2, Room: R2, Station: 5 Condition: D, DbTeamID: 35, total_sims: 12, unique_sims: 11, pareto_rank: 1.2, pareto_rank_ordinal: 3
#  Day: M, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 8, total_sims: 11, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S3, Room: R2, Station: 5 Condition: A, DbTeamID: 43, total_sims: 18, unique_sims: 13, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 33, total_sims: 18, unique_sims: 14, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: T, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 31, total_sims: 13, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S2, Room: R2, Station: 7 Condition: D, DbTeamID: 9, total_sims: 8, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S4, Room: R1, Station: 2 Condition: B, DbTeamID: 45, total_sims: 14, unique_sims: 13, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R1, Station: 4 Condition: B, DbTeamID: 20, total_sims: 12, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R2, Station: 7 Condition: A, DbTeamID: 41, total_sims: 11, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R1, Station: 1 Condition: D, DbTeamID: 37, total_sims: 12, unique_sims: 11, pareto_rank: 1.25, pareto_rank_ordinal: 4
#  Day: T, Session: S4, Room: R2, Station: 5 Condition: A, DbTeamID: 49, total_sims: 12, unique_sims: 10, pareto_rank: 1.25, pareto_rank_ordinal: 4
#  Day: M, Session: S4, Room: R2, Station: 8 Condition: A, DbTeamID: 22, total_sims: 11, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S1, Room: R1, Station: 1 Condition: A, DbTeamID: 1, total_sims: 9, unique_sims: 9, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S3, Room: R1, Station: 3 Condition: A, DbTeamID: 13, total_sims: 18, unique_sims: 14, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S2, Room: R2, Station: 6 Condition: D, DbTeamID: 36, total_sims: 9, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S3, Room: R1, Station: 4 Condition: A, DbTeamID: 14, total_sims: 16, unique_sims: 12, pareto_rank: 1.3333333333333333, pareto_rank_ordinal: 5
#  Day: M, Session: S4, Room: R1, Station: 1 Condition: B, DbTeamID: 17, total_sims: 12, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 50, total_sims: 10, unique_sims: 9, pareto_rank: 1.25, pareto_rank_ordinal: 4
#  Day: M, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 5, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R2, Station: 7 Condition: A, DbTeamID: 21, total_sims: 14, unique_sims: 14, pareto_rank: 4.5, pareto_rank_ordinal: 8
#  Day: T, Session: S1, Room: R2, Station: 5 Condition: D, DbTeamID: 29, total_sims: 8, unique_sims: 4, pareto_rank: 4.333333333333333, pareto_rank_ordinal: 7
#  Day: M, Session: S2, Room: R1, Station: 2 Condition: B, DbTeamID: 6, total_sims: 14, unique_sims: 12, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 24, total_sims: 10, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 19, total_sims: 10, unique_sims: 7, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S2, Room: R1, Station: 3 Condition: B, DbTeamID: 7, total_sims: 11, unique_sims: 9, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: M, Session: S2, Room: R2, Station: 6 Condition: D, DbTeamID: 11, total_sims: 15, unique_sims: 15, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S1, Room: R2, Station: 6 Condition: D, DbTeamID: 30, total_sims: 9, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S1, Room: R1, Station: 1 Condition: B, DbTeamID: 25, total_sims: 6, unique_sims: 5, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: M, Session: S4, Room: R1, Station: 2 Condition: B, DbTeamID: 18, total_sims: 12, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 46, total_sims: 9, unique_sims: 8, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S3, Room: R2, Station: 8 Condition: A, DbTeamID: 42, total_sims: 14, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R1, Station: 4 Condition: D, DbTeamID: 40, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 10, total_sims: 11, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S3, Room: R2, Station: 8 Condition: D, DbTeamID: 16, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S1, Room: R2, Station: 8 Condition: D, DbTeamID: 28, total_sims: 10, unique_sims: 10, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: T, Session: S3, Room: R1, Station: 2 Condition: D, DbTeamID: 38, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S1, Room: R1, Station: 3 Condition: A, DbTeamID: 3, total_sims: 13, unique_sims: 12, pareto_rank: 1.5, pareto_rank_ordinal: 6

# %%
bestA = [analyzed_data[k] for k in analyzed_data.keys() if 
         analyzed_data[k].condition == 'A' and analyzed_data[k].pareto_ranks_ordinal == 2]

for best in bestA:
    print(best)
# Out:
#  Day: M, Session: S1, Room: R1, Station: 4 Condition: A, DbTeamID: 4, total_sims: 10, unique_sims: 9, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S3, Room: R1, Station: 1 Condition: A, DbTeamID: 12, total_sims: 9, unique_sims: 8, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R2, Station: 7 Condition: A, DbTeamID: 41, total_sims: 11, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R2, Station: 8 Condition: A, DbTeamID: 22, total_sims: 11, unique_sims: 11, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: M, Session: S4, Room: R2, Station: 6 Condition: A, DbTeamID: 24, total_sims: 10, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2
#  Day: T, Session: S3, Room: R2, Station: 8 Condition: A, DbTeamID: 42, total_sims: 14, unique_sims: 10, pareto_rank: 0.5, pareto_rank_ordinal: 2

# %%
worstA = [analyzed_data[k] for k in analyzed_data.keys() if 
         analyzed_data[k].condition == 'A' and analyzed_data[k].pareto_ranks_ordinal == 8]

for worst in worstA:
    print(worst)
# Out:
#  Day: M, Session: S4, Room: R2, Station: 7 Condition: A, DbTeamID: 21, total_sims: 14, unique_sims: 14, pareto_rank: 4.5, pareto_rank_ordinal: 8

# %%
bestB = [analyzed_data[k] for k in analyzed_data.keys() if 
         analyzed_data[k].condition == 'B' and analyzed_data[k].pareto_ranks_ordinal == 1]

# %%
for best in bestB:
    print(best)
# Out:
#  Day: T, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 33, total_sims: 18, unique_sims: 14, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: M, Session: S2, Room: R1, Station: 3 Condition: B, DbTeamID: 7, total_sims: 11, unique_sims: 9, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1

# %%
worstB = [analyzed_data[k] for k in analyzed_data.keys() if 
         analyzed_data[k].condition == 'B' and analyzed_data[k].pareto_ranks_ordinal >= 6]
for worst in worstB:
    print(worst)
# Out:
#  Day: M, Session: S2, Room: R1, Station: 4 Condition: B, DbTeamID: 8, total_sims: 11, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S2, Room: R1, Station: 1 Condition: B, DbTeamID: 31, total_sims: 13, unique_sims: 10, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S1, Room: R1, Station: 1 Condition: B, DbTeamID: 25, total_sims: 6, unique_sims: 5, pareto_rank: 1.5, pareto_rank_ordinal: 6
#  Day: T, Session: S4, Room: R1, Station: 3 Condition: B, DbTeamID: 46, total_sims: 9, unique_sims: 8, pareto_rank: 1.5, pareto_rank_ordinal: 6

# %%
bestD = [analyzed_data[k] for k in analyzed_data.keys() if 
         analyzed_data[k].condition == 'D' and analyzed_data[k].pareto_ranks_ordinal == 1]
for best in bestD:
    print(best)
# Out:
#  Day: M, Session: S3, Room: R2, Station: 7 Condition: D, DbTeamID: 15, total_sims: 7, unique_sims: 6, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1
#  Day: T, Session: S1, Room: R2, Station: 8 Condition: D, DbTeamID: 28, total_sims: 10, unique_sims: 10, pareto_rank: 0.3333333333333333, pareto_rank_ordinal: 1

# %%
worstD = [analyzed_data[k] for k in analyzed_data.keys() if 
         analyzed_data[k].condition == 'D' and analyzed_data[k].pareto_ranks_ordinal >= 7]
for worst in worstD:
    print(worst)
# Out:
#  Day: T, Session: S2, Room: R2, Station: 8 Condition: D, DbTeamID: 34, total_sims: 5, unique_sims: 5, pareto_rank: 4.333333333333333, pareto_rank_ordinal: 7
#  Day: T, Session: S1, Room: R2, Station: 5 Condition: D, DbTeamID: 29, total_sims: 8, unique_sims: 4, pareto_rank: 4.333333333333333, pareto_rank_ordinal: 7

# %%
font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 16}

matplotlib.rc('font', **font)

golden_ratio = np.array([1.61803398875, 1])
golden_ratio_byN = np.array([1.61803398875, 2/3])
plt.figure(figsize=golden_ratio_byN*6)

paretoRanksA = np.array(paretoRanksA)
paretoRanksB = np.array(paretoRanksB)
paretoRanksD = np.array(paretoRanksD)

plt.hist(paretoRanksA-1/6, bins=np.arange(0, 9, 1/6), density=False)
plt.hist(paretoRanksB+0/6, bins=np.arange(0, 9, 1/6), density=False)
plt.hist(paretoRanksD+1/6, bins=np.arange(0, 9, 1/6), density=False)
plt.xlim([0, 9])
plt.legend(conditions, fontsize=12, loc='upper right')
plt.ylabel('Number of Teams')
plt.xlabel('Pareto Rank (lower is better)')
plt.show()

# %%
print(f'{conditions[0]}\n(mean, std) = ({np.mean(paretoRanksA)}, {np.std(paretoRanksA)})\n')
print(f'{conditions[1]}\n(mean, std) = ({np.mean(paretoRanksB)}, {np.std(paretoRanksB)})\n')
print(f'{conditions[2]}\n(mean, std) = ({np.mean(paretoRanksD)}, {np.std(paretoRanksD)})\n')
paretoRanksBD = np.append(paretoRanksB, paretoRanksD)
print(f'{conditions[1]}, {conditions[2]}\n(mean, std) = ({np.mean(paretoRanksBD)}, {np.std(paretoRanksBD)})\n')
# Out:
# A - control (discuss conference) at beginning
# (mean, std) = (4.071428571428571, 2.016513459070443)
#
# B - strategy at beginning
# (mean, std) = (3.2142857142857144, 1.9704448891619601)
#
# D - strategy at mid
# (mean, std) = (3.0, 1.96638416050035)
#
# B - strategy at beginning, D - strategy at mid
# (mean, std) = (3.103448275862069, 1.971255990062959)

# %%
print(len(paretoRanksA))
print(len(paretoRanksB))
print(len(paretoRanksD))
# Out:
# 14
# 14
# 15

# %%
t2, p2 = scipy.stats.ttest_ind(paretoRanksA,paretoRanksB)
print("t = " + str(t2))
print("p = " + str(p2))
# Out:
# t = 1.0961479993399592
# p = 0.28306371432975796

# %%
t2, p2 = scipy.stats.ttest_ind(paretoRanksA,paretoRanksD)
print("t = " + str(t2))
print("p = " + str(p2))
# Out:
# t = 1.39746760649165
# p = 0.1736515077503668
